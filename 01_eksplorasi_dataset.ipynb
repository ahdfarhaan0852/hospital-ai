# %%
# Sel 1 — import library
import pandas as pd
import numpy as np

# %%
file_path = r'C:\Users\LENOVO\hospital-ai\data\diet_mapping.xlsx'

try:
    df_diet = pd.read_excel(file_path)
    print("File berhasil dibaca!")
    display(df_diet.tail(10))
except Exception as e:
    print(f"Terjadi kesalahan: {e}")
# Out:
# Terjadi kesalahan: Missing optional dependency 'openpyxl'.  Use pip or conda to install openpyxl.

# %%
print("Kolom diet_mapping:", df_diet.columns.tolist())
print("Kolom menu:", df_menu.columns.tolist())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Sel 4 — cek nama kolom (pastikan sesuai dengan yang kamu rancang)
# ----> 2 print("Kolom diet_mapping:", df_diet.columns.tolist())
#       3 print("Kolom menu:", df_menu.columns.tolist())
#
# NameError: name 'df_diet' is not defined

# %%
# Sel 5 — cek apakah ada data kosong (missing values)
print("=== Diet Mapping ===")
print(df_diet.isnull().sum())
print("\n=== Menu Dataset ===")
print(df_menu.isnull().sum())
# Out:
# === Diet Mapping ===
# No.                    0
# Nama Menu              0
# Tipe Diet/Deskripsi    0
# Kalori                 0
# Protein_g              9
# Lemak_g                9
# Karbohidrat_g          9
# dtype: int64
#
# === Menu Dataset ===
# No.                    0
# Nama Menu              0
# Tipe Diet/Deskripsi    0
# Kalori                 0
# Protein_g              9
# Lemak_g                9
# Karbohidrat_g          9
# dtype: int64

# %%
# Sel 6 — cek distribusi jenis_diet di dataset menu
print("Jenis diet yang ada di menu:")
print(df_menu['jenis_diet'].value_counts())
# Out:
# Jenis diet yang ada di menu:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
# --> 167 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
# --> 196 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7088 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
# Sel 7 — cek distribusi waktu_makan
print("Waktu makan:")
print(df_menu['waktu_makan'].value_counts())
# Out:
# Waktu makan:
# waktu_makan
# Makan Siang    5
# Sarapan        4
# Makan Malam    2
# Snack          1
# Name: count, dtype: int64

# %%
# Sel 8 — cek statistik nilai nutrisi
df_menu[['kalori_kcal','protein_g','lemak_g','karbohidrat_g']].describe()
# Out:
#        kalori_kcal  protein_g    lemak_g  karbohidrat_g
# count    12.000000  12.000000  12.000000      12.000000
# mean    370.000000  21.416667   8.500000      47.000000
# std      69.282032   7.178989   2.969542      10.392305
# min     280.000000  10.000000   5.000000      30.000000
# 25%     307.500000  17.250000   6.000000      38.750000
# 50%     365.000000  21.000000   8.000000      51.000000
# 75%     427.500000  25.750000  10.500000      55.000000
# max     480.000000  35.000000  14.000000      60.000000
